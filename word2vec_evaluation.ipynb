# %% [markdown]
# # Tiny Shakespeare

# %% [markdown]
# CBOW with basic tokenization, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file safe_vectors/cbow_tiny_shakespeare_basic_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.10408617044543278
# Bi-gram score using euclidean distance (between -1 and 1): 0.1197783771961799
# Perplexity using cosine similarity: 6622.532743542643
# Perplexity using euclidean distance: 5943.14202636894

# %% [markdown]
# Skip-gram with basic tokenization, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file safe_vectors/skipgram_tiny_shakespeare_basic_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.18438798571116133
# Bi-gram score using euclidean distance (between -1 and 1): -0.20655026609316907
# Perplexity using cosine similarity: 5649.677383816104
# Perplexity using euclidean distance: 5952.145410373282

# %% [markdown]
# CBOW with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_shakespeare_super_tokens_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.15873015873015883
# Bi-gram score using euclidean distance (between -1 and 1): -0.06622879036672136
# Perplexity using cosine similarity: 5600.127832853438
# Perplexity using euclidean distance: 6567.3435651100435

# %% [markdown]
# Skip-gram with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_shakespeare_super_tokens_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.15249266862170097
# Bi-gram score using euclidean distance (between -1 and 1): 0.16788856304985333
# Perplexity using cosine similarity: 5465.751173521937
# Perplexity using euclidean distance: 6252.965356168242

# %% [markdown]
# CBOW with basic tokenization, sigmoid activation function, and adam optimizer:

# %%
# %run evaluate.py -vector_file safe_vectors/cbow_tiny_shakespeare_basic_window10_chars250000_sigmoid_adam.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.031165706787198433
# Bi-gram score using euclidean distance (between -1 and 1): 0.03920317853758115
# Perplexity using cosine similarity: 7516.172203323879
# Perplexity using euclidean distance: 4942.836024534164

# %% [markdown]
# Skip-gram with basic tokenization, sigmoid activation function, and adam optimizer:

# %%
# %run evaluate.py -vector_file safe_vectors/skipgram_tiny_shakespeare_basic_window10_chars250000_sigmoid_adam.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.16911496682948168
# Bi-gram score using euclidean distance (between -1 and 1): 0.10663774877888754
# Perplexity using cosine similarity: 7129.607934712876
# Perplexity using euclidean distance: 3124.015129875233

# %% [markdown]
# CBOW with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, SGD, and random window sizes:

# %%
# %run evaluate.py -vector_file safe_vectors/cbow_tiny_shakespeare_super_tokens_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.13842364532019702
# Bi-gram score using euclidean distance (between -1 and 1): -0.22561576354679813
# Perplexity using cosine similarity: 6187.857064667089
# Perplexity using euclidean distance: 5363.046771515032

# %% [markdown]
# Skip-gram with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, SGD, and random window sizes:

# %%
# %run evaluate.py -vector_file safe_vectors/skipgram_tiny_shakespeare_super_tokens_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.0761133603238866
# Bi-gram score using euclidean distance (between -1 and 1): 0.0380566801619433
# Perplexity using cosine similarity: 5713.375980884065
# Perplexity using euclidean distance: 5548.827327419825

# %% [markdown]
# CBOW with Subsampling of Frequent Words and Learned Phrases tokens, sigmoid activation function, adam optimizer, and random window sizes:

# %%
# %run evaluate.py -vector_file safe_vectors/cbow_tiny_shakespeare_super_tokens_window10_chars250000_sigmoid_adam.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.2703001200480193
# Bi-gram score using euclidean distance (between -1 and 1): 0.3184153661464586
# Perplexity using cosine similarity: 4809.6390189009835
# Perplexity using euclidean distance: 5316.5956344911365

# %% [markdown]
# Skip-gram with Subsampling of Frequent Words and Learned Phrases tokens, sigmoid activation function, adam optimizer, and random window sizes:

# %%
# %run evaluate.py -vector_file safe_vectors/skipgram_tiny_shakespeare_super_tokens_window10_chars250000_sigmoid_adam.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.24787644787644791
# Bi-gram score using euclidean distance (between -1 and 1): -0.04427284427284417
# Perplexity using cosine similarity: 6247.488207839292
# Perplexity using euclidean distance: 4798.796140200975

# %% [markdown]
# # IMDb

# %% [markdown]
# CBOW with basic tokenization, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_imdb_basic_window10_chars300000_softmax_SGD.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.16319955817378495
# Bi-gram score using euclidean distance (between -1 and 1): -0.16334420366084568
# Perplexity using cosine similarity: 8972.819009351011
# Perplexity using euclidean distance: 7336.649239540587

# %% [markdown]
# Skip-gram with basic tokenization, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_imdb_basic_window10_chars300000_softmax_SGD.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.035319798022301674
# Bi-gram score using euclidean distance (between -1 and 1): -0.021157689880075825
# Perplexity using cosine similarity: 7789.518451080228
# Perplexity using euclidean distance: 7248.848616519386

# %% [markdown]
# CBOW with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_imdb_super_tokens_window10_chars300000_softmax_SGD.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.3494854549874402
# Bi-gram score using euclidean distance (between -1 and 1): 0.2767198768333198
# Perplexity using cosine similarity: 8316.669498097142
# Perplexity using euclidean distance: 6551.208235043466

# %% [markdown]
# Skip-gram with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, and SGD:

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_imdb_super_tokens_window10_chars300000_softmax_SGD.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.029870129870129825
# Bi-gram score using euclidean distance (between -1 and 1): 0.0051948051948051965
# Perplexity using cosine similarity: 7290.669954391073
# Perplexity using euclidean distance: 7063.654606339029

# %% [markdown]
# CBOW with basic tokenization, sigmoid activation function, and adam optimizer:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_imdb_basic_window10_chars300000_sigmoid_adam.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.09983168525142017
# Bi-gram score using euclidean distance (between -1 and 1): -0.05894961077214389
# Perplexity using cosine similarity: 7476.307851233091
# Perplexity using euclidean distance: 6719.215544949071

# %% [markdown]
# Skip-gram with basic tokenization, sigmoid activation function, and adam optimizer:

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_imdb_basic_window10_chars300000_sigmoid_adam.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.20664580265095733
# Bi-gram score using euclidean distance (between -1 and 1): -0.02030296654744368
# Perplexity using cosine similarity: 8186.713314779962
# Perplexity using euclidean distance: 3904.459894102065

# %% [markdown]
# CBOW with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, SGD, and random window sizes:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_imdb_super_tokens_window10_chars300000_softmax_SGD_rand.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.12461538461538457
# Bi-gram score using euclidean distance (between -1 and 1): 0.13538461538461544
# Perplexity using cosine similarity: 6427.6892556300145
# Perplexity using euclidean distance: 7444.709326386708

# %% [markdown]
# Skip-gram with Subsampling of Frequent Words and Learned Phrases tokens, softmax activation function, SGD, and random window sizes:

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_imdb_super_tokens_window10_chars300000_softmax_SGD_rand.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.007894736842105288
# Bi-gram score using euclidean distance (between -1 and 1): -0.10263157894736841
# Perplexity using cosine similarity: 7439.9468224462535
# Perplexity using euclidean distance: 6742.599812012559

# %% [markdown]
# CBOW with Subsampling of Frequent Words and Learned Phrases tokens, sigmoid activation function, adam optimizer, and random window sizes:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_imdb_super_tokens_window10_chars300000_sigmoid_adam_rand.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.16574440052700923
# Bi-gram score using euclidean distance (between -1 and 1): -0.19749670619235826
# Perplexity using cosine similarity: 4874.517768643952
# Perplexity using euclidean distance: 7396.43326309466

# %% [markdown]
# Skip-gram with Subsampling of Frequent Words and Learned Phrases tokens, sigmoid activation function, adam optimizer, and random window sizes:

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_imdb_super_tokens_window10_chars300000_sigmoid_adam_rand.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.10811984368215377
# Bi-gram score using euclidean distance (between -1 and 1): 0.014112027789839332
# Perplexity using cosine similarity: 7021.305867870419
# Perplexity using euclidean distance: 6035.8646450950255

# %% [markdown]
# # More bi-gram testing

# %% [markdown]
# Shakespeare:

# %%
# %run evaluate.py -vector_file safe_vectors/cbow_tiny_shakespeare_basic_window10_chars250000_softmax_SGD.json -evaluate_file large_shakespeare_eval.txt -metric bigram
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.11564654384885698
# Bi-gram score using euclidean distance (between -1 and 1): -0.03499409420107402

# %%
# %run evaluate.py -vector_file safe_vectors/skipgram_tiny_shakespeare_basic_window10_chars250000_softmax_SGD.json -evaluate_file large_shakespeare_eval.txt -metric bigram
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.002911994856479083
# Bi-gram score using euclidean distance (between -1 and 1): -0.08359018458825052

# %% [markdown]
# IMDb:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_imdb_basic_window10_chars300000_softmax_SGD.json -evaluate_file large_imdb_eval.txt -metric bigram
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.10523006670882307
# Bi-gram score using euclidean distance (between -1 and 1): -0.04047278471736493

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_imdb_basic_window10_chars300000_softmax_SGD.json -evaluate_file large_imdb_eval.txt -metric bigram
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.04628171393452618
# Bi-gram score using euclidean distance (between -1 and 1): -0.10372077171034855

# %% [markdown]
# # Research extension: Smoothing

# %% [markdown]
# Learn word embeddings:

# %%
# %run word2vec.py -model cbow -file tiny_shakespeare.txt -tokenizer oov
# Out:
# WARNING:tensorflow:From C:\Users\sarah\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\sarah\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/1000
# 44950/44950 [==============================] - 9s 202us/sample - loss: 0.0036 - acc: 0.9996
# Epoch 2/1000
# 44950/44950 [==============================] - 9s 197us/sample - loss: 0.0036 - acc: 0.9996
# Epoch 3/1000
# ...

# %%
# %run word2vec.py -model skipgram -file tiny_shakespeare.txt -tokenizer oov
# Out:
# Epoch 1/1000
# 44950/44950 [==============================] - 9s 206us/sample - loss: 0.0564 - acc: 0.9928
# Epoch 2/1000
# 44950/44950 [==============================] - 9s 206us/sample - loss: 0.0564 - acc: 0.9928
# Epoch 3/1000
# 44950/44950 [==============================] - 9s 206us/sample - loss: 0.0564 - acc: 0.9928
# Epoch 4/1000
# 44950/44950 [==============================] - 9s 208us/sample - loss: 0.0564 - acc: 0.9928
# Epoch 5/1000
# 44950/44950 [==============================] - 9s 206us/sample - loss: 0.0563 - acc: 0.9928
# Epoch 6/1000
# 44950/44950 [==============================] - 9s 205us/sample - loss: 0.0563 - acc: 0.9928
# Epoch 7/1000
# 44950/44950 [==============================] - 9s 205us/sample - loss: 0.0563 - acc: 0.9928
# Epoch 8/1000
# 44950/44950 [==============================] - 9s 205us/sample - loss: 0.0563 - acc: 0.9928s - loss: 0.0563 - acc: 0.9
# Epoch 9/1000
# ...

# %%
# %run word2vec.py -model cbow -file tiny_imdb.txt -max_chars 300000 -tokenizer oov
# Out:
# Epoch 1/1000
# 44128/44128 [==============================] - 9s 205us/sample - loss: 0.0031 - acc: 0.9996s - loss: 0.
# Epoch 2/1000
# 44128/44128 [==============================] - 9s 203us/sample - loss: 0.0031 - acc: 0.9996
# Epoch 3/1000
# 44128/44128 [==============================] - 9s 203us/sample - loss: 0.0031 - acc: 0.9996
# Epoch 4/1000
# 44128/44128 [==============================] - 9s 202us/sample - loss: 0.0031 - acc: 0.9996
# Epoch 5/1000
# 44128/44128 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.999 - 9s 203us/sample - loss: 0.0031 - acc: 0.9996
# Epoch 6/1000
# 44128/44128 [==============================] - 9s 203us/sample - loss: 0.0031 - acc: 0.9996
# Epoch 7/1000
# 44128/44128 [==============================] - 9s 203us/sample - loss: 0.0031 - acc: 0.9996s - loss: 0.003 - ETA:
# Epoch 8/1000
# 44128/44128 [==============================] - 9s 203us/sample - loss: 0.0031 - acc: 0.9996
# Epoch 9/1000
# ...

# %%
# %run word2vec.py -model skipgram -file tiny_imdb.txt -max_chars 300000 -tokenizer oov
# Out:
# Epoch 1/1000
# 44128/44128 [==============================] - 10s 216us/sample - loss: 0.0484 - acc: 0.9940
# Epoch 2/1000
# 44128/44128 [==============================] - 9s 215us/sample - loss: 0.0484 - acc: 0.9940
# Epoch 3/1000
# 44128/44128 [==============================] - 10s 216us/sample - loss: 0.0484 - acc: 0.9940
# Epoch 4/1000
# 44128/44128 [==============================] - 9s 213us/sample - loss: 0.0484 - acc: 0.9940
# Epoch 5/1000
# 44128/44128 [==============================] - 9s 212us/sample - loss: 0.0484 - acc: 0.9940
# Epoch 6/1000
# 44128/44128 [==============================] - 9s 212us/sample - loss: 0.0484 - acc: 0.9940
# Epoch 7/1000
# 44128/44128 [==============================] - 9s 213us/sample - loss: 0.0483 - acc: 0.9940
# Epoch 8/1000
# 44128/44128 [==============================] - 9s 214us/sample - loss: 0.0483 - acc: 0.9940s - loss: 0
# Epoch 9/1000
# ...

# %% [markdown]
# Evaluation:

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_shakespeare_oov_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): 0.02837837837837842
# Bi-gram score using euclidean distance (between -1 and 1): 0.11237276237276239
# Perplexity using cosine similarity: 3126.415349681031
# Perplexity using euclidean distance: 2427.8736526631906

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_shakespeare_oov_window10_chars250000_softmax_SGD.json -evaluate_file shakespeare_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.10476482976482981
# Bi-gram score using euclidean distance (between -1 and 1): 0.14426991926991928
# Perplexity using cosine similarity: 2659.6528193473077
# Perplexity using euclidean distance: 2462.9183946918624

# %%
# %run evaluate.py -vector_file vectors/cbow_tiny_imdb_oov_window10_chars300000_softmax_SGD.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.037681159420289934
# Bi-gram score using euclidean distance (between -1 and 1): -0.07958328528043679
# Perplexity using cosine similarity: 4731.639410905765
# Perplexity using euclidean distance: 3134.5389618650097

# %%
# %run evaluate.py -vector_file vectors/skipgram_tiny_imdb_oov_window10_chars300000_softmax_SGD.json -evaluate_file imdb_eval.txt
# Out:
# Loaded vector_file
# Loaded evaluate_file
# Bi-gram score using cosine similarity (between -1 and 1): -0.12583708145927042
# Bi-gram score using euclidean distance (between -1 and 1): 0.055380002306539056
# Perplexity using cosine similarity: 3072.5240966078054
# Perplexity using euclidean distance: 3103.7026189487838

# %% [markdown]
# # Application: Netflix recommender

# %%
# %run word2vec_application.py
# Out:
# Epoch 1/1000
# 6231/6231 [==============================] - 11s 2ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 2/1000
# 6231/6231 [==============================] - 10s 2ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 3/1000
# 6231/6231 [==============================] - 9s 2ms/sample - loss: 0.0071 - acc: 0.9994 0s - loss: 0.0071 - acc: 0.99
# Epoch 4/1000
# 6231/6231 [==============================] - 10s 2ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 5/1000
# 6231/6231 [==============================] - 19s 3ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 6/1000
# 6231/6231 [==============================] - 21s 3ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 7/1000
# 6231/6231 [==============================] - 20s 3ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 8/1000
# 6231/6231 [==============================] - 20s 3ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 9/1000
# 6231/6231 [==============================] - 15s 2ms/sample - loss: 0.0071 - acc: 0.9994
# Epoch 10/1000
# ...

# %% [markdown]
# If you like "Friends", maybe you'll like...

# %%
# %run recommender.py -preference friends
# Out:
# Loaded vector_file
# Your recommended titles: ['beautiesofthenight', 'hurricanebianca', 'trailerparkboys:xmasspecial', 'llamallama', 'thehardway', 'theperfectdictatorship', '#selfie', 'hisss', 'belowhermouth', "amar'shands"]

# %% [markdown]
# Some of these make a lot of sense! Hurricane Bianca, The Perfect Dictatorship, and #Selfie are all light-hearted comedies like "Friends". However, the point of treating everything except the title of the TV show/movie as the "context" is that some of the reommended titles would have the same actors, directors, etc. as well, which did not happen above. Let's try it with another TV show:

# %%
# %run recommender.py -preference gossipgirl
# Out:
# Loaded vector_file
# Your recommended titles: ['bibi&tina:girlsversusboys', 'theforce', 'thebleeder', 'topgrier', 'thegentlemandriver', 'teshan', 'insatiable', 'mythomaniac', 'thestranger', 'mysterysciencetheater3000:thereturn']

# %% [markdown]
# Bibi & Tina is about teenage girls, Top Grier is "trashy" reality series, and Insatiable is a TV show comparable to Gossip Girl. For some reason, a decent amount of the titles are also sports movies, but a lot of them were dramas, making them decent recommendations. However, as with "Friends" these recommendations don't seem to utilize information about the actors, etc. Let's check out one more TV show:

# %%
# %run recommender.py -preference strangerthings
# Out:
# Loaded vector_file
# Your recommended titles: ['khan:no.1crimehunter', 'thebyebyeman', 'kristy', 'fangbone', 'merepapaherohiralal', 'davidbrent:lifeontheroad', 'lorai:playtolive', 'bitterdaisies', 'loquelaverdadesconde:elcasoasunta(operacionnenúfar)', 'elchavo']

# %% [markdown]
# Khan: No. 1 Crime Hunter, The Bye Bye Man, Kristy, Fangbone, Bitter Daisies, and Lo que la verdad esconde: El caso Asunta (Operacion Nenufar) all have some sort of mystery, crime, and/or mystical element to them, which make them pretty good recommendations for people who like Stranger Things! This was probably the best set of recommendations yet. Now let's try out a movie:

# %%
# %run recommender.py -preference blackpanther
# Out:
# Loaded vector_file
# Your recommended titles: ['johnmulaney:thecomebackkid', '7daysout', 'thetruthaboutalcohol', "he'soutthere", 'thek2', 'thehollywoodmasters', 'koshish', 'intothebadlands', 'mariabamford:oldbaby', 'yandakartavyaaahe', 'thedisastrouslifeofsaikik.:reawakened']

# %% [markdown]
# Into the Badlands and The Disastrous Life of Saiki K.: Reawakened are the only recommendations which kind of make sense. All of the others are stand-up comedy specials or romance-related, which don't really make sense as recommendations for a superhero action movie like Black Panther.
